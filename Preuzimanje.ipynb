# %%
#skidanje netcdf podataka po godinama i mjesecima
# svi url-ovi:

url1 = 'https://repozitorij.meteo.hr/data/regcm4-2017-lvl1/RES_12/GCM_CN/EXP_historical/'
# url1 = 'https://repozitorij.meteo.hr/data/regcm4-2017-lvl1/RES_12/GCM_CN/EXP_rcp45/'
# url1 = 'https://repozitorij.meteo.hr/data/regcm4-2017-lvl1/RES_12/GCM_CN/EXP_rcp85/'

# url1 = 'https://repozitorij.meteo.hr/data/regcm4-2017-lvl1/RES_12/GCM_EC/EXP_historical/'
# url1 = 'https://repozitorij.meteo.hr/data/regcm4-2017-lvl1/RES_12/GCM_EC/EXP_rcp45/'
# url1 = 'https://repozitorij.meteo.hr/data/regcm4-2017-lvl1/RES_12/GCM_EC/EXP_rcp85/'

# url1 = 'https://repozitorij.meteo.hr/data/regcm4-2017-lvl1/RES_12/GCM_HA/EXP_historical/'
# url1 = 'https://repozitorij.meteo.hr/data/regcm4-2017-lvl1/RES_12/GCM_HA/EXP_rcp45/'
# url1 = 'https://repozitorij.meteo.hr/data/regcm4-2017-lvl1/RES_12/GCM_HA/EXP_rcp85/'

# url1 = 'https://repozitorij.meteo.hr/data/regcm4-2017-lvl1/RES_12/GCM_MP/EXP_historical/'
# url1 = 'https://repozitorij.meteo.hr/data/regcm4-2017-lvl1/RES_12/GCM_MP/EXP_rcp45/'
# url1 = 'https://repozitorij.meteo.hr/data/regcm4-2017-lvl1/RES_12/GCM_MP/EXP_rcp85/'

# Varijable koje skidamo (ukupno24varijable):
# url2 = 'tasmax_CRO_CN_STS.{}{}0100.nc'
# url2 = 'tasmin_CRO_CN_STS.{}{}0100.nc'

# Historical godine idu od: 1mj.1970god. - 11mj.2005god. 
# RCP godine idu od: 12mj.2005god. - 12mj.2070god.

import requests
j = 1970 # početna godina
while j < 2006:
    for i in range(1,14):
        if i < 10:
            print ('god = {}, mj = {}'.format(j,i))
            url = url1 + 'tasmax_CRO_CN_STS.{}0{}0100.nc'.format(j,i) #to mijenjamo ovisno o gcm-u i rcp-u
            r = requests.get(url, allow_redirects=True)
            open('{}_{}.nc'.format(i,j), 'wb').write(r.content)
        elif i < 13:
            print ('god = {}, mj = {}'.format(j,i))
            url = url1 + 'tasmax_CRO_CN_STS.{}{}0100.nc'.format(j,i) #to mijenjamo ovisno o gcm-u i rcp-u
            r = requests.get(url, allow_redirects=True)
            open('{}_{}.nc'.format(i,j), 'wb').write(r.content)
        elif i == 13:
            j += 1
# Out:
# god = 1970, mj = 1
# god = 1970, mj = 2
# god = 1970, mj = 3
# god = 1970, mj = 4
# god = 1970, mj = 5
# god = 1970, mj = 6
# god = 1970, mj = 7
# god = 1970, mj = 8
# god = 1970, mj = 9
# god = 1970, mj = 10
# god = 1970, mj = 11
# god = 1970, mj = 12
# god = 1971, mj = 1
# god = 1971, mj = 2
# god = 1971, mj = 3
# god = 1971, mj = 4
# god = 1971, mj = 5
# god = 1971, mj = 6
# god = 1971, mj = 7
# god = 1971, mj = 8
# god = 1971, mj = 9
# god = 1971, mj = 10
# god = 1971, mj = 11
# god = 1971, mj = 12
# god = 1972, mj = 1
# god = 1972, mj = 2
# god = 1972, mj = 3
# god = 1972, mj = 4
# god = 1972, mj = 5
# god = 1972, mj = 6
# god = 1972, mj = 7
# god = 1972, mj = 8
# god = 1972, mj = 9
# god = 1972, mj = 10
# god = 1972, mj = 11
# god = 1972, mj = 12
# god = 1973, mj = 1
# god = 1973, mj = 2
# god = 1973, mj = 3
# god = 1973, mj = 4
# god = 1973, mj = 5
# god = 1973, mj = 6
# god = 1973, mj = 7
# god = 1973, mj = 8
# god = 1973, mj = 9
# god = 1973, mj = 10
# god = 1973, mj = 11
# ...
